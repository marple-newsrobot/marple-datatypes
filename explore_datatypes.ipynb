# %%
import pandas as pd

# %%
df = pd.read_csv("datatypes.csv")
df = df.sort_values("id")
z = 'id required description value_type nullable allowed_values'.split()
df = df[z]
df
# Out:
#                   id required  \
# 0          age_group    False
# 1      city_district    False
# 2            country    False
# 3   country_of_birth    False
# 4             county    False
# 5         crime_code    False
# 6         crime_type    False
# 7               date    False
# 8             gender    False
# 9            measure    False
# 10             month    False
# 11      municipality    False
# 12            period    False
# 13       periodicity    False
# 14           quarter    False
# 15            region    False
# 16         source_id    False
# 17             value    False
# 18              year    False
#
#                                           description value_type nullable  \
# 0                                                 NaN        str    False
# 1     An administrative subdivision of a municipality        str    False
# 2                          A country, past or present        str    False
# ...

# %%
df.to_csv("datatypes.csv",index=False)
